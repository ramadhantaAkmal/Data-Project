# %% [markdown]
# # Web Scraping Comment Youtube

# %%
from youtube_comment_scraper_python import *
import pandas as pd

youtube.open("https://www.youtube.com/watch?v=sX55W2hpGoY")
all_data=[]
for i in range(0,20):
    response=youtube.video_comments()
    data=response['body']
    all_data.extend(data)

df = pd.DataFrame(data)
# Out:
# Starting DataKund...
# Progress:  65%|██████▍   | 129.23076923076923/200 [00:26<00:16,  4.39it/s]
# Progress:  83%|████████▎ | 165.3846153846154/200 [00:32<00:06,  5.24it/s]
# Progress:  98%|█████████▊| 196.15384615384616/200 [00:34<00:00,  7.29it/s][A
# Progress: 210.0it [00:38,  5.82it/s]                                      [A
# Progress: 215.71428571428572it [00:40,  5.16it/s][00:10<00:14,  7.66it/s]
# Progress: 221.42857142857144it [00:43,  4.60it/s][00:12<00:15,  6.49it/s]
# Progress: 228.57142857142858it [00:45,  4.32it/s] [00:14<00:17,  5.45it/s]
# Progress: 234.28571428571428it [00:47,  3.92it/s] [00:16<00:19,  4.66it/s]
# Progress: 240.0it [00:49,  3.60it/s]              [00:18<00:20,  4.10it/s]
# Progress: 245.71428571428572it [00:51,  3.37it/s] [00:20<00:21,  3.68it/s]
# Progress: 250.0it [00:53,  3.00it/s]             [00:22<00:21,  3.40it/s]
# Progress: 255.71428571428572it [00:55,  2.95it/s] [00:24<00:21,  3.21it/s]
# ...

# %%
df
# Out:
#                                                Comment Likes          Time  \
# 0    hehehe, asli ini iklan the best bgt,  ngalahin...    83  2 months ago
# 1    Ini yg bikin skenario dan kata-katanya siapa s...   350  2 months ago
# 2    Sumpah iklan nya keren bgt. Selalu suka kalo A...   152  2 months ago
# 3    Dalam hal apapun Boriel selalu memberikan yang...    47  2 months ago
# 4    cinematic dapet, comedy dapet, punch line dape...    77  2 months ago
# ..                                                 ...   ...           ...
# 395                        Kren bang bor.. Lanjutt lah     9  2 months ago
# 396  Njiss Alus si Boriel apa aja cocok dia mah ya....     3  2 months ago
# 397  Kaarena seepaaaatuuu aaaaakuuuu diiii siiniiii...     5  2 months ago
# 398  Edaaannn, iklannya udah kyak short movie comed...     6  2 months ago
# 399                              Hahahaha ariel mantap     3  2 months ago
#
#                               UserLink                 user
# ...

# %%
df.to_csv("Gojek_CepetanGoSendInstant by Ariel NOAH x GoSend_comments.csv")
